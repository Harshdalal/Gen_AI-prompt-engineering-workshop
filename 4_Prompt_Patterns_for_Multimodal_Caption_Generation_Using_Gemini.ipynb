# %% [markdown]
# #🧪 Practical: Prompt Patterns for Multimodal Caption Generation Using Gemini

# %% [markdown]
# 🔹 Step 1: Install Required Library

# %%
# !pip install -q google-generativeai

# %% [markdown]
# 🔹 Step 2: Import Libraries and Configure Gemini API

# %%
import google.generativeai as genai
from PIL import Image
import IPython.display as display

# Configure Gemini with your API key
genai.configure(api_key="AIzaSyCOQXtLBKUXIlw4p-jarVeENvtvmnBPLiw")  # Replace with your actual key

# %% [markdown]
# 🔹 Step 3: Load the Multimodal Gemini Model

# %%
# Load the multimodal model
vision_model = genai.GenerativeModel(model_name="gemini-1.5-flash-latest")

# %% [markdown]
# 🔹 Step 4: Load and Display an Image

# %%
# Load image (replace path with your image)
image_path = "sample_image.jpg"  # You can also upload via Colab or Jupyter

# Open and show the image
image = Image.open(image_path)
display.display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768>

# %% [markdown]
# 🔹 Step 5: Prompt Pattern 1 – Descriptive Captioning

# %%
# Simple description prompt
prompt1 = "Describe this image in detail."

response1 = vision_model.generate_content([prompt1, image])
print("📝 Descriptive Caption:\n", response1.text)
# Out:
# 📝 Descriptive Caption:
#  Here's a description of the image:
#
# Close-up view of a Golden Retriever puppy lying in the grass.
#
#
# Here's a breakdown of the details:
#
# * **The Puppy:** The puppy is light cream or pale gold in color, with soft, fluffy fur. Its face is the main focus, showcasing large, expressive brown eyes, a slightly upturned nose, and a pink tongue partially visible in its open mouth. The puppy appears to be very young, possibly only a few weeks or months old. Its ears are floppy and a slightly darker shade of cream than its body.
#
# * **The Setting:** The puppy is nestled in vibrant green grass, which is slightly out of focus, drawing attention to the sharpness of the puppy. The background is a blurred, dark green, suggesting a natural outdoor setting, possibly a garden or park. The background is out of focus, creating a bokeh effect that isolates the puppy.
#
# ...

# %% [markdown]
# 🔹 Step 6: Prompt Pattern 2 – Creative Captioning

# %%
# Creative storytelling style caption
prompt2 = "Write a creative and imaginative caption for this image as if it's a scene from a storybook."

response2 = vision_model.generate_content([prompt2, image])
print("🎨 Creative Caption:\n", response2.text)
# Out:
# 🎨 Creative Caption:
#  Here are a few caption options for the image, in a storybook style:
#
# **Option 1 (Sweet & Simple):**
#
# "And there, nestled amongst the emerald blades, lay Pip, the golden pup. His heart, as bright as his fur, held the promise of a thousand adventures."
#
#
# **Option 2 (A Bit More Mysterious):**
#
# "The Whispering Meadows held a secret.  A secret with soft fur and paws that padded silently.  This was Barnaby, and his journey was only just beginning..."
#
#
# **Option 3 (Focus on the character's personality):**
#
# "Little Sunny, brave and bold, surveyed his kingdom. The sun warmed his golden coat, and the scent of wildflowers filled his joyful heart."
#
#
# **Option 4 (More whimsical):**
#
# "From a land of sunshine and sweet dreams, came Goldie, a fluffball of pure delight.  His wagging tail promised mischief and cuddles in equal measure."
#
#
# **Option 5 (Slightly darker, hinting at a quest):**
#
# ...

# %% [markdown]
# 🔹 Step 7: Prompt Pattern 3 – Instructional Captioning

# %%
# Caption as if for educational use
prompt3 = "Explain what is happening in this image for a classroom lesson."

response3 = vision_model.generate_content([prompt3, image])
print("📚 Instructional Caption:\n", response3.text)
# Out:
# 📚 Instructional Caption:
#  Here's a classroom lesson explanation of the image:
#
# **Subject:** Observing Animals and Their Environments
#
# **Image Description:** The picture shows a Golden Retriever puppy lying in a grassy field. The puppy is light-colored, fluffy, and appears to be young.  Its mouth is slightly open, and it looks alert and curious. The background is blurred, focusing attention on the puppy. The grass is green and relatively short.
#
# **Lesson Points:**
#
# 1. **Animal Identification:**  This is a Golden Retriever puppy. Discuss the breed's characteristics:  golden coat, friendly expression, medium-to-large size (when fully grown). You can expand on breeds and their unique traits.  Ask the students if they've seen other dogs of different breeds.
#
# ...

# %% [markdown]
# 🔹 Step 8: Optional – Use Function for Reusability

# %%
def caption_image(image, prompt_style):
    prompt_map = {
        "descriptive": "Describe this image in detail.",
        "creative": "Write a creative and imaginative caption for this image.",
        "instructional": "Explain what is happening in this image as if for a classroom lesson."
    }
    prompt = prompt_map.get(prompt_style.lower(), "Describe the image.")
    response = vision_model.generate_content([prompt, image])
    return response.text

# Try it
print(caption_image(image, "creative"))
# Out:
# Here are a few caption options for the image of the Golden Retriever puppy:
#
# **Option 1 (Cute & Simple):**
#
# "Pure golden sunshine. ☀️"
#
# **Option 2 (A Bit More Descriptive):**
#
# "This little fluffball just melted my heart.  Puppy breath and endless cuddles, please! 😍"
#
# **Option 3 (Playful):**
#
# "Warning: May spontaneously cause excessive 'awws' and uncontrollable petting.  Proceed with caution.  🐶"
#
# **Option 4 (More Poetic):**
#
# "A tiny cloud of gold, nestled in a field of dreams."
#
# **Option 5 (Question to Engage Audience):**
#
# "What's the cutest thing a puppy has ever done?  This little one's a contender for sure! 👇"
#
#
# Choose the caption that best suits your style and intended audience.  Remember to use relevant hashtags if posting on social media (e.g., #goldenretriever #puppy #cute #dogsofinstagram).

# %% [markdown]
# #✅ Summary Table
#
# | Prompt Style  | Description                             |
# | ------------- | --------------------------------------- |
# | Descriptive   | Plain, factual description of the image |
# | Creative      | Artistic, story-like caption            |
# | Instructional | Explains the image like a teacher would |
